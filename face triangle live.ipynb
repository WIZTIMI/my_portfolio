# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
def draw_rect(x,y,w,h):
   # (x,y,w,h) = face
    return cv2.rectangle(frame,(x,y),(x +w, y+h),(0,255,255),4 ) 
    ## rectanglebox/x and y axis/x is the width, 
#y is the height (grid), color na color, width of rectangle

# %%
def face_detection(image):
    #raed image
    img=cv2.imread(image)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
    faces = face_cascade.detectMultiScale(gray, 1.3,5)
    x,y,w,h = faces[0] #flatten
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255), thickness = 8)
    return plt.imshow(face_img)

# %%
face_detection("ronaldo.jpg")

# %%
cap = cv2.VideoCapture(0)
while True:
    result, frame = cap.read()
    if result is False:
        break
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")
    faces = face_cascade.detectMultiScale(gray, 1.3,5)
    for x,y,w,h in faces:
        cv2.rectangle(frame, (x,y), (x+w, y+h),(0,0,255),4)
    cv2.imshow("Face Detection", frame)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
cap.release()
cv2.destroyAllWindows()
