# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df =pd.read_csv("train.csv")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
df.Item_Type.unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
df.Item_Identifier.unique()
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'NCF55', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
df.Outlet_Size.unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
df.Outlet_Type.unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
df["Item_Fat_Content"].replace({"low fat":"Low fat","reg":"Regular"}, inplace = True)
# Out:
# C:\Users\mac\AppData\Local\Temp\ipykernel_11864\2170277820.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Item_Fat_Content"].replace({"low fat":"Low fat","reg":"Regular"}, inplace = True)

# %%
df.isnull().sum()/8523*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
df.Outlet_Size.mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
df.Outlet_Size.fillna("Medium", inplace = True)
# Out:
# C:\Users\mac\AppData\Local\Temp\ipykernel_11864\3627345832.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Outlet_Size.fillna("Medium", inplace = True)

# %%
df.Item_Weight.mean()
# Out:
# np.float64(12.857645184135976)

# %%
df.Item_Weight.fillna("12.85", inplace = True)
# Out:
# C:\Users\mac\AppData\Local\Temp\ipykernel_11864\1752902154.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Item_Weight.fillna("12.85", inplace = True)
# C:\Users\mac\AppData\Local\Temp\ipykernel_11864\1752902154.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '12.85' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.Item_Weight.fillna("12.85", inplace = True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
b = { "Medium" : 1, "High" : 2, "Small" : 3 }

# %%
a= { "Supermarket Type1" : 2222, "Supermarket Type2" : 3333, "Grocery Store" : 4444,
       "Supermarket Type3" : 5555 }

# %%
a
# Out:
# {'Supermarket Type1': 2222,
#  'Supermarket Type2': 3333,
#  'Grocery Store': 4444,
#  'Supermarket Type3': 5555}

# %%
b
# Out:
# {'Medium': 1, 'High': 2, 'Small': 3}

# %%
df.Outlet_Type = df.Outlet_Type.map(a)

# %%
df.Outlet_Size = df.Outlet_Size.map(b)

# %%
a = {"Low Fat": 0, "Regular": 1}

# %%
df.Item_Fat_Content =  df.Item_Fat_Content.map(a)

# %%
df
# Out:
#      Item_Identifier Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.3               0.0         0.016047
# 1              DRC01        5.92               1.0         0.019278
# 2              FDN15        17.5               0.0         0.016760
# 3              FDX07        19.2               1.0         0.000000
# 4              NCD19        8.93               0.0         0.000000
# ...              ...         ...               ...              ...
# 8518           FDF22       6.865               0.0         0.056783
# 8519           FDS36        8.38               1.0         0.046982
# 8520           NCJ29        10.6               0.0         0.035186
# 8521           FDN46        7.21               1.0         0.145221
# 8522           DRG01        14.8               0.0         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.Outlet_Location_Type.unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
a = {"Tier 1" : 0, "Tier 3" : 1, "Tier 2" : 2}

# %%
df.Outlet_Location_Type.map(a)
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 8518    1
# 8519    2
# 8520    2
# 8521    1
# 8522    0
# Name: Outlet_Location_Type, Length: 8523, dtype: int64

# %%
df.Outlet_Location_Type = df.Outlet_Location_Type.map(a)

# %%
df
# Out:
#      Item_Identifier Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.3               0.0         0.016047
# 1              DRC01        5.92               1.0         0.019278
# 2              FDN15        17.5               0.0         0.016760
# 3              FDX07        19.2               1.0         0.000000
# 4              NCD19        8.93               0.0         0.000000
# ...              ...         ...               ...              ...
# 8518           FDF22       6.865               0.0         0.056783
# 8519           FDS36        8.38               1.0         0.046982
# 8520           NCJ29        10.6               0.0         0.035186
# 8521           FDN46        7.21               1.0         0.145221
# 8522           DRG01        14.8               0.0         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
# dropping a column
#df.drop("Item_Type", axis = 1, inplace =True)

# %%
#df.drop("Outlet_Identifier", axis = 1, inplace =True)

# %%
df
# Out:
#      Item_Identifier Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.3               0.0         0.016047
# 1              DRC01        5.92               1.0         0.019278
# 2              FDN15        17.5               0.0         0.016760
# 3              FDX07        19.2               1.0         0.000000
# 4              NCD19        8.93               0.0         0.000000
# ...              ...         ...               ...              ...
# 8518           FDF22       6.865               0.0         0.056783
# 8519           FDS36        8.38               1.0         0.046982
# 8520           NCJ29        10.6               0.0         0.035186
# 8521           FDN46        7.21               1.0         0.145221
# 8522           DRG01        14.8               0.0         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df
# Out:
#      Item_Weight  Item_Fat_Content  Item_Visibility              Item_Type  \
# 0            9.3               0.0         0.016047                  Dairy
# 1           5.92               1.0         0.019278            Soft Drinks
# 2           17.5               0.0         0.016760                   Meat
# 3           19.2               1.0         0.000000  Fruits and Vegetables
# 4           8.93               0.0         0.000000              Household
# ...          ...               ...              ...                    ...
# 8518       6.865               0.0         0.056783            Snack Foods
# 8519        8.38               1.0         0.046982           Baking Goods
# 8520        10.6               0.0         0.035186     Health and Hygiene
# 8521        7.21               1.0         0.145221            Snack Foods
# 8522        14.8               0.0         0.044878            Soft Drinks
#
# ...

# %%
## FEATURE SELECTION IS ABOUT HOW YOU SELECT COLUMS THAT WILL BE YOUR INPUT OR OUTPUT

# %% [markdown]
# ### FEATURE SELECTION

# %% [markdown]
# df.corr()

# %%
#df.drop("Item_Identifier", axis = 1, inplace =True)

# %%
df
# Out:
#      Item_Weight  Item_Fat_Content  Item_Visibility              Item_Type  \
# 0            9.3               0.0         0.016047                  Dairy
# 1           5.92               1.0         0.019278            Soft Drinks
# 2           17.5               0.0         0.016760                   Meat
# 3           19.2               1.0         0.000000  Fruits and Vegetables
# 4           8.93               0.0         0.000000              Household
# ...          ...               ...              ...                    ...
# 8518       6.865               0.0         0.056783            Snack Foods
# 8519        8.38               1.0         0.046982           Baking Goods
# 8520        10.6               0.0         0.035186     Health and Hygiene
# 8521        7.21               1.0         0.145221            Snack Foods
# 8522        14.8               0.0         0.044878            Soft Drinks
#
# ...

# %%
df.drop("Item_Type", axis = 1, inplace =True)

# %%
df
# Out:
#      Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0            9.3               0.0         0.016047  249.8092
# 1           5.92               1.0         0.019278   48.2692
# 2           17.5               0.0         0.016760  141.6180
# 3           19.2               1.0         0.000000  182.0950
# 4           8.93               0.0         0.000000   53.8614
# ...          ...               ...              ...       ...
# 8518       6.865               0.0         0.056783  214.5218
# 8519        8.38               1.0         0.046982  108.1570
# 8520        10.6               0.0         0.035186   85.1224
# 8521        7.21               1.0         0.145221  103.1332
# 8522        14.8               0.0         0.044878   75.4670
#
#      Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0               OUT049                       1999            1
# 1               OUT018                       2009            1
# ...

# %%
df.drop("Outlet_Identifier", axis = 1, inplace =True)

# %%
df
# Out:
#      Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0            9.3               0.0         0.016047  249.8092
# 1           5.92               1.0         0.019278   48.2692
# 2           17.5               0.0         0.016760  141.6180
# 3           19.2               1.0         0.000000  182.0950
# 4           8.93               0.0         0.000000   53.8614
# ...          ...               ...              ...       ...
# 8518       6.865               0.0         0.056783  214.5218
# 8519        8.38               1.0         0.046982  108.1570
# 8520        10.6               0.0         0.035186   85.1224
# 8521        7.21               1.0         0.145221  103.1332
# 8522        14.8               0.0         0.044878   75.4670
#
#       Outlet_Establishment_Year  Outlet_Size  Outlet_Location_Type  \
# 0                          1999            1                     0
# 1                          2009            1                     1
# ...

# %%
df.corr()
## correlation must be 0.7 above
# Out:
#                            Item_Weight  Item_Fat_Content  Item_Visibility  \
# Item_Weight                   1.000000         -0.022882        -0.012112
# Item_Fat_Content             -0.022882          1.000000         0.049785
# Item_Visibility              -0.012112          0.049785         1.000000
# Item_MRP                      0.024762          0.004157        -0.001315
# Outlet_Establishment_Year    -0.007825          0.001184        -0.074834
# Outlet_Size                   0.003210         -0.001796         0.049712
# Outlet_Location_Type         -0.010978         -0.004425        -0.076912
# Outlet_Type                   0.001424          0.002202         0.124445
# Item_Outlet_Sales             0.011495          0.016955        -0.128625
#
#                            Item_MRP  Outlet_Establishment_Year  Outlet_Size  \
# Item_Weight                0.024762                  -0.007825     0.003210
# ...

# %%
df =df[["Outlet_Location_Type","Outlet_Size","Outlet_Type","Item_Outlet_Sales","Item_MRP"]]

# %%
df
# Out:
#       Outlet_Location_Type  Outlet_Size  Outlet_Type  Item_Outlet_Sales  \
# 0                        0            1         2222          3735.1380
# 1                        1            1         3333           443.4228
# 2                        0            1         2222          2097.2700
# 3                        1            1         4444           732.3800
# 4                        1            2         2222           994.7052
# ...                    ...          ...          ...                ...
# 8518                     1            2         2222          2778.3834
# 8519                     2            1         2222           549.2850
# 8520                     2            3         2222          1193.1136
# 8521                     1            1         3333          1845.5976
# 8522                     0            3         2222           765.6700
#
#       Item_MRP
# 0     249.8092
# 1      48.2692
# 2     141.6180
# 3     182.0950
# 4      53.8614
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
## check for outliers

# %%
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dd9fc41df0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dd9fc42270>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dd9f9cd430>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1dd9fc427e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1dd9fc42a20>,
# ...
#  'means': []}

# %%
plt.boxplot(df["Item_Outlet_Sales"])
plt.show()

# %%
## handling outliers using log

# %%
df.Item_Outlet_Sales =np.log(df.Item_Outlet_Sales)
# Out:
# C:\Users\mac\AppData\Local\Temp\ipykernel_11864\4134745467.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Item_Outlet_Sales =np.log(df.Item_Outlet_Sales)

# %%
plt.boxplot(df["Item_Outlet_Sales"])
plt.show()

# %%
df = df[df["Item_Outlet_Sales"] >5]

# %%
df
# Out:
#       Outlet_Location_Type  Outlet_Size  Outlet_Type  Item_Outlet_Sales  \
# 0                        0            1         2222           8.225540
# 1                        1            1         3333           6.094524
# 2                        0            1         2222           7.648392
# 3                        1            1         4444           6.596300
# 4                        1            2         2222           6.902446
# ...                    ...          ...          ...                ...
# 8518                     1            2         2222           7.929625
# 8519                     2            1         2222           6.308617
# 8520                     2            3         2222           7.084322
# 8521                     1            1         3333           7.520558
# 8522                     0            3         2222           6.640751
#
#       Item_MRP
# 0     249.8092
# 1      48.2692
# 2     141.6180
# 3     182.0950
# 4      53.8614
# ...

# %%
plt.boxplot(df["Item_Outlet_Sales"])
plt.show()

# %%
import numpy as np

# %%
x = df.drop("Item_Outlet_Sales", axis = 1)

# %%
x
# Out:
#       Outlet_Location_Type  Outlet_Size  Outlet_Type  Item_MRP
# 0                        0            1         2222  249.8092
# 1                        1            1         3333   48.2692
# 2                        0            1         2222  141.6180
# 3                        1            1         4444  182.0950
# 4                        1            2         2222   53.8614
# ...                    ...          ...          ...       ...
# 8518                     1            2         2222  214.5218
# 8519                     2            1         2222  108.1570
# 8520                     2            3         2222   85.1224
# 8521                     1            1         3333  103.1332
# 8522                     0            3         2222   75.4670
#
# [8254 rows x 4 columns]

# %%
y = df.Item_Outlet_Sales

# %%
y
# Out:
# 0       8.225540
# 1       6.094524
# 2       7.648392
# 3       6.596300
# 4       6.902446
#           ...
# 8518    7.929625
# 8519    6.308617
# 8520    7.084322
# 8521    7.520558
# 8522    6.640751
# Name: Item_Outlet_Sales, Length: 8254, dtype: float64

# %%
x.shape
# Out:
# (8254, 4)

# %%
y.shape
# Out:
# (8254,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, random_state = 10)

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
LR.predict(x_test)
# Out:
# array([7.45792569, 7.37163781, 7.958849  , ..., 8.24587482, 7.48282844,
#        7.22923405])

# %%
y_test
# Out:
# 4866    7.402775
# 142     7.670371
# 7178    7.950258
# 8416    6.830293
# 5995    7.181051
#           ...
# 439     8.188869
# 1833    7.593584
# 7635    7.954709
# 1649    8.356349
# 6453    7.608231
# Name: Item_Outlet_Sales, Length: 2064, dtype: float64

# %%
## now do the mean squared error

# %%
from sklearn.metrics import mean_squared_error

# %%
predicted_values =LR.predict(x_test)

# %%
mean_squared_error(y_test,predicted_values)
# Out:
# np.float64(0.597356949408856)

# %%
#### it is not called 60% but 0.6 erroe value

# %%
### intercept model
LR.intercept_
# Out:
# np.float64(6.7410388076641246)

# %%
plt.scatter(y_test,predicted_values, c = "black")
plt.plot(y_test,y_test, c= "red")
plt.xlabel("ACTUAL VALUES")
plt.ylabel("PREDICTED VALUES")
plt.show()

# %%
LR.predict([[0,1,2222,249.8092]])
# Out:
# C:\Users\mac\miniconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8.17808922])
